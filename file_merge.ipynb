# %%
import pandas as pd

# %%
recommended_songs = pd.read_csv('recommended_song.csv', index_col=0)
recommmeded_song_analysis = pd.read_csv('recommended_song_audio_features.csv', index_col= 0)

# %%
recommended_songs.dtypes
# Out:
# name          object
# artist        object
# id            object
# popularity     int64
# dtype: object

# %%
recommmeded_song_analysis.dtypes
# Out:
# index                 int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# dtype: object

# %%
print(len(recommended_songs))
print(len(recommmeded_song_analysis))
# Out:
# 237683
# 237700

# %%
recommended_song_df = pd.merge(recommended_songs, recommmeded_song_analysis, left_index=True, right_index=True)

# %%
recommended_song_df
# Out:
#                                              name            artist  \
# 0             Dont Worry (its on me) - Radio Edit       Sir William
# 1                                    Slow It Down        Short Dawg
# 2                           Club Paradise - Remix          Kigity K
# 3       Chanel Vintage (feat. Future, Young Thug)      Metro Boomin
# 4                                       Dedicated          The Game
# ...                                           ...               ...
# 237678                               Finesse Gawd      Bryce Oliver
# 237679                          Giving My All 2 U               WEB
# 237680                                I MISS 2007  poptropicaslutz!
# 237681                       drugs you should try      Deep October
# 237682                              CHAINSAW MAN!         Steele 11
#
#                           id_x  popularity  index  danceability  energy  key  \
# ...

# %%
recommended_song_df.to_csv('merged_df.csv')
